# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans

# fetching datasets
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-c238692e-9e7b-4f1c-82b7-c2aa0a210040" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c238692e-9e7b-4f1c-82b7-c2aa0a210040">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# fetching dataset - 1
df1 = pd.read_csv('EV Stats-1.csv')
df1.head()
# Out:
#    Sl. No           State  \
# 0       1  Andhra Pradesh
# 1       2           Assam
# 2       3           Bihar
# 3       4    Chhattisgarh
# 4       5           Delhi
#
#    Two Wheelers (Category L1 & L2 as per Central Motor Vehicles Rules  \
# 0                                                431
# 1                                                463
# 2                                                252
# 3                                                613
# 4                                               1395
#
#    Two Wheelers (Category L2 (CMVR))  \
# 0                                692
# 1                                138
# 2                                430
# 3                                382
# 4                                251
#
#    Two Wheelers (Max power not exceeding 250 Watts)  \
# 0                                              4689
# 1                                              1006
# 2                                              2148
# ...

# %%
uploaded = files.upload()
df2 = pd.read_csv('Indian automoble buying behavour study 1.0.csv')
df2.head()
# Out:
#      <input type="file" id="files-52a9fa14-0db2-42ec-91be-60828ea0a44d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-52a9fa14-0db2-42ec-91be-60828ea0a44d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
uploaded = files.upload()
df3 = pd.read_csv('EV Dataset-3.csv')
df3.head()
# Out:
#      <input type="file" id="files-15bdceec-6da7-4cc0-bb26-cb5ed6725b43" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-15bdceec-6da7-4cc0-bb26-cb5ed6725b43">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# checking the shape (# of rows and columns) of the datasets
print('DF1 Shape: ', df1.shape)
print('DF2 Shape: ', df2.shape)
print('DF3 Shape: ', df3.shape)
# Out:
# DF1 Shape:  (35, 10)
# DF2 Shape:  (99, 13)
# DF3 Shape:  (103, 14)

# %%
# getting a statistical summary of the datasets
d1 = df1.describe()
d2 = df2.describe()
d3 = df3.describe()
display('DATASET 1 ', d1, ' DATASET 2 ', d2, 'DATASET 3', d3)
# Out:
# 'DATASET 1 '
#           Sl. No  \
# count  31.000000
# mean   16.000000
# std     9.092121
# min     1.000000
# 25%     8.500000
# 50%    16.000000
# 75%    23.500000
# max    31.000000
#
#        Two Wheelers (Category L1 & L2 as per Central Motor Vehicles Rules  \
# count                                          31.000000
# mean                                         1777.354839
# std                                          5000.160994
# min                                             0.000000
# 25%                                            22.000000
# 50%                                           463.000000
# 75%                                          1089.500000
# max                                         27549.000000
#
#        Two Wheelers (Category L2 (CMVR))  \
# count                          31.000000
# mean                          907.677419
# std                          2518.917378
# min                             0.000000
# ...

# %%
# analysis of two wheeler vehicles from dataset-1
plt.figure(figsize=(6, 6))
sns.barplot(data=df1, y=df1['State'].sort_values(ascending=True),x='Two Wheelers (Category L1 & L2 as per Central Motor Vehicles Rules', palette='viridis')
plt.ylabel('State', fontsize=14, family='serif')
plt.xlabel('Number of EV: 2 Wheelers(L1 & L2)', family='serif', fontsize=14, labelpad=10)
plt.xticks(family='serif')
plt.yticks(family='serif')
plt.title(label='Statewise Electric Vehicles (2 Wheelers L1 and L2 category) in India', weight=200, family='serif', size=15, pad=12)
plt.show()

# %%
plt.figure(figsize=(6, 6))
sns.barplot(data=df1, y=df1['State'].sort_values(ascending=True),x='Two Wheelers (Max power not exceeding 250 Watts)', palette='viridis')
plt.ylabel('State', fontsize=14, family='serif')
plt.xlabel('Number of EV: Two Wheelers (Max power not exceeding 250 Watts)', family='serif', fontsize=14, labelpad=10)
plt.xticks(family='serif')
plt.yticks(family='serif')
plt.title(label='Statewise Electric Vehicles(Max power not exceeding 250 Watts) in India', weight=200, family='serif', size=15, pad=12)
plt.show()

# %%
plt.figure(figsize=(6, 6))
sns.barplot(data=df1, y=df1['State'].sort_values(ascending=True),x='Three Wheelers (Category L5 as per CMVR)', palette='viridis')
plt.ylabel('State', fontsize=14, family='serif')
plt.xlabel('Number of EV: Three Wheelers (Category L5 as per CMVR)', family='serif', fontsize=14, labelpad=10)
plt.xticks(family='serif')
plt.yticks(family='serif')
plt.title(label='Statewise Three Wheeler Electric Vehicles (Category L5 as per CMVR) in India', weight=200, family='serif', size=15, pad=12)
plt.show()

# %%
plt.figure(figsize=(6, 6))
sns.barplot(data=df1, y=df1['State'].sort_values(ascending=True),x='Passenger Cars (Category M1 as per CMVR)', palette='viridis')
plt.ylabel('State', fontsize=14, family='serif')
plt.xlabel('Number of EV:Passenger Cars (Category M1 as per CMVR)', family='serif', fontsize=14, labelpad=10)
plt.xticks(family='serif')
plt.yticks(family='serif')
plt.title(label='Statewise Passenger Cars (Category M1 as per CMVR) in India', weight=200, family='serif', size=15, pad=12)
plt.show()

# %%
plt.figure(figsize=(6, 6))
sns.barplot(data=df1, y=df1['State'].sort_values(ascending=True),x='Buses', palette='viridis')
plt.ylabel('State', fontsize=14, family='serif')
plt.xlabel('Number of EV:Buses', family='serif', fontsize=14, labelpad=10)
plt.xticks(family='serif')
plt.yticks(family='serif')
plt.title(label='Statewise Electric Buses in India', weight=200, family='serif', size=15, pad=12)
plt.show()

# %%
plt.figure(figsize=(6, 6))
sns.barplot(data=df1, y=df1['State'].sort_values(ascending=True),x='Total in state', palette='viridis')
plt.ylabel('State', fontsize=14, family='serif')
plt.xlabel('Number of EV:Total in state', family='serif', fontsize=14, labelpad=10)
plt.xticks(family='serif')
plt.yticks(family='serif')
plt.title(label='Statewise Total Electric Vehicles in every state in India', weight=200, family='serif', size=15, pad=12)
plt.show()

# %%
# analysis of data in dataset-2
x = df2['Profession'].value_counts().plot.pie(radius=1.5, cmap='viridis', startangle=0, textprops=dict(family='serif'),autopct='%1.1f%%')
plt.pie(x=[1], radius=1.0, colors='white')
plt.title(label='Profession of the respondents', family='serif', size=15, pad=100)
plt.ylabel('')
plt.show()

# %%
import plotly.express as px
age = df2["Age"].value_counts()
fig = px.bar(age, title="Age of respondents")
fig.update_layout(
    xaxis_title = "Age",
    yaxis_title = "Frequency",
    title_x = 0.5,
    showlegend = False
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
x = df2['Marrital Status'].value_counts().plot.pie(radius=1.5, cmap='viridis', startangle=0, textprops=dict(family='serif'),autopct='%1.1f%%')
plt.pie(x=[1], radius=1.0, colors='white')
plt.title(label='Marital Status of electric Vehicle owners in india ', family='serif', size=15, pad=100)
plt.ylabel('')
plt.show()

# %%
x = df2['Education'].value_counts().plot.pie(radius=1.5, cmap='viridis', startangle=0, textprops=dict(family='serif'),autopct='%1.1f%%')
plt.pie(x=[1], radius=1.0, colors='white')
plt.title(label='Highest Educational qualification of electric Vehicle owners in india ', family='serif', size=15, pad=100)
plt.ylabel('')
plt.show()

# %%
sal = df2["Total Salary"].value_counts()
fig = px.bar(sal, title="Total Salary of respondents")
fig.update_layout(
    xaxis_title = "Salary",
    yaxis_title = "Frequency",
    title_x = 0.5,
    showlegend = False
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
x = df2['Make'].value_counts().plot.pie(radius=2.0, cmap='viridis', startangle=0,textprops=dict(family='serif'),autopct='%1.1f%%')
plt.pie(x=[1], radius=1.0, colors='white')
plt.axis('equal')
plt.title(label='Preference of cars make in india ', family='serif', size=15, pad=100)
plt.ylabel('')
plt.show()

# %%
price = df2["Price"].value_counts()
fig = px.bar(price, title="Price of car")
fig.update_layout(
    xaxis_title = "Price",
    yaxis_title = "Frequency",
    title_x = 0.5,
    showlegend = False
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
sns.catplot(data=df3, x='Brand', kind='count', palette='viridis', height=6, aspect=2.5)
sns.despine(right=False, top=False)
plt.tick_params(axis='x', rotation=40)
name = df3["Brand"].value_counts()
fig = px.bar(name, title="Number of EV models manufactured by brand")
fig.update_layout(
    xaxis_title = "Brand Name",
    yaxis_title = "Frequency",
    title_x = 0.5,
    showlegend = False
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
x = df3['BodyStyle'].value_counts().plot.pie(radius=2.5, cmap='viridis', startangle=0,textprops=dict(family='serif'),autopct='%1.1f%%')
plt.pie(x=[1], radius=1.0, colors='white')
plt.axis('equal')
plt.title(label='EV Bodystyle Preferences', family='serif', size=15, pad=100)
plt.ylabel('')
plt.show()

# %%
x = df3['Segment'].value_counts().plot.pie(radius=2.5, cmap='viridis', startangle=0,textprops=dict(family='serif'),autopct='%1.1f%%')
plt.pie(x=[1], radius=1.0, colors='white')
plt.axis('equal')
plt.title(label='Segment Preferences', family='serif', size=15, pad=100)
plt.ylabel('')
plt.show()

# %%
x = df3['Seats'].value_counts().plot.pie(radius=2.5, cmap='viridis', startangle=0,textprops=dict(family='serif'),autopct='%1.1f%%')
plt.pie(x=[1], radius=1.0, colors='white')
plt.axis('equal')
plt.title(label='Seat Capacity Preferences', family='serif', size=15, pad=100)
plt.ylabel('')
plt.show()

# %%
for label, content in df3.items():
    if not pd.api.types.is_numeric_dtype(df3[label]):
        lst = df3[label].unique()
        label_map = {}
        for i in range(len(lst)):
            label_map[lst[i]] = i
        df3[label] = df3[label].map(label_map)
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Brand            103 non-null    int64
#  1   Model            103 non-null    int64
#  2   AccelSec         103 non-null    float64
#  3   TopSpeed_KmH     103 non-null    int64
#  4   Range_Km         103 non-null    int64
#  5   Efficiency_WhKm  103 non-null    int64
#  6   FastCharge_KmH   103 non-null    int64
#  7   RapidCharge      103 non-null    int64
#  8   PowerTrain       103 non-null    int64
#  9   PlugType         103 non-null    int64
#  10  BodyStyle        103 non-null    int64
#  11  Segment          103 non-null    int64
#  12  Seats            103 non-null    int64
#  13  PriceEuro        103 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 11.4 KB

# %%
plt.figure(figsize=(15,5))
sns.heatmap(df3.corr(), annot=True)
# Out:
# <Axes: >

# %%
from sklearn.cluster import KMeans
from scipy.cluster.hierarchy import linkage, dendrogram
from sklearn.cluster import AgglomerativeClustering

wcss = []
for k in range(1, 15):
    kmeans = KMeans(n_clusters=k)
    kmeans.fit(df3)
    wcss.append(kmeans.inertia_)

plt.figure(figsize=(15, 5))
plt.plot(range(1, 15), wcss)
plt.xlabel('Number of clusters')
plt.ylabel('wcss')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning:
#
# ...

# %%
kmeans = KMeans(4, init = 'k-means++', random_state=42).fit(df3)
df3['cluster_number'] = kmeans.labels_
from sklearn.decomposition import PCA
from sklearn import preprocessing

x = df3.values
pca = preprocessing.scale(x)
pca = PCA(n_components=13)
pca = pca.fit_transform(x)

pf = pd.DataFrame(data=pca, columns=[f"PC{i+1}" for i in range(13)])
sns.scatterplot(data=pf, x='PC1', y='PC2', hue=kmeans.labels_)
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], marker='+', c="r", s=50, label='centroids')
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
